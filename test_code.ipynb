# %%
print ('hello')
# Out:
# hello

# %%
print('Why')
# Out:
# Why

# %%
import data_extract

# %%
data_extract.get_bat_dat()
# Out:
#               Reduced Cell Formula  Average Voltage (V)  Min Voltage (V)  \
# Battery ID
# mp-504791_Li               P(WO4)2             2.325185         2.325185
# mp-763480_Li               P3W2O13             3.291748         3.291748
# mp-1176966_Li              P8W3O29             3.609671         2.660169
# mvc-5592_Li                  P2WO7             3.201169         3.201169
# mp-763566_Li                 P2WO7             2.438309         2.438309
# ...                            ...                  ...              ...
# mp-1180276_Mg              VCu3Se4            -0.098693        -0.098693
# mp-1042619_Mg           Cu3(SnO3)4             1.890890         1.890890
# mp-1046932_Mg          BaTl(NiO3)2             3.071616         3.071616
# mp-1041103_Mg            Ho(MoO3)2             1.982244         1.982244
# mvc-4401_Mg              Ge3(WO6)2             1.663489         1.663489
#
#                Max Voltage (V)  Number of Steps  Min Instability  \
# ...
